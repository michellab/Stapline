# %%
import pandas as pd

# %%
RR_data_ref= pd.read_csv("~/Desktop/RR_run1.csv")
RR_data= pd.read_csv("~/Desktop/RR_run2.csv")
SS_data= pd.read_csv("~/Desktop/SS_run1.csv")

# %%
rms_RR = ( abs(RR_data -RR_data_ref)/abs(RR_data_ref)  ).sum(axis=0)
rms_SS = ( abs(SS_data -RR_data_ref)/abs(RR_data_ref)  ).sum(axis=0)

# %%
rms_SS.plot.bar()
# Out:
# <Axes: >

# %%
rms_RR.plot.bar()
# Out:
# <Axes: >
